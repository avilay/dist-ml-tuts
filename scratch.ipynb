# %%
from dataclasses import dataclass
import numpy as np
import pandas as pd

# %%
FILEPATH = "/Users/avilayparekh/mldata/kaggle-criteo/small_train.txt"

# %%
cols = ["Label"] + [f"I{i}" for i in range(1, 14)] + [f"C{i}" for i in range(1, 27)]
cols
# Out:
# ['Label',
#  'I1',
#  'I2',
#  'I3',
#  'I4',
#  'I5',
#  'I6',
#  'I7',
#  'I8',
#  'I9',
#  'I10',
#  'I11',
#  'I12',
#  'I13',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'C6',
#  'C7',
#  'C8',
#  'C9',
#  'C10',
#  'C11',
#  'C12',
#  'C13',
#  'C14',
#  'C15',
#  'C16',
#  'C17',
#  'C18',
#  'C19',
#  'C20',
#  'C21',
#  'C22',
#  'C23',
#  'C24',
#  'C25',
#  'C26']

# %%
df = pd.read_csv(FILEPATH, sep="\t", header=None, names=cols)

# %%
df.head(5)
# Out:
#    Label   I1  I2    I3   I4      I5     I6    I7    I8     I9  ...       C17  \
# 0      1  NaN   0   1.0  4.0  8530.0   89.0  56.0   3.0  653.0  ...  e5ba7672
# 1      0  0.0  -1   NaN  NaN  4173.0   35.0   1.0   2.0   31.0  ...  d4bb7bd8
# 2      0  0.0  32  63.0  8.0   240.0  135.0  10.0  48.0  130.0  ...  e5ba7672
# 3      0  NaN   1   5.0  NaN  2838.0   39.0   1.0   0.0    9.0  ...  d4bb7bd8
# 4      0  NaN  14   0.0  2.0  6999.0   18.0   8.0   2.0   64.0  ...  3486227d
#
#         C18       C19       C20       C21  C22       C23       C24       C25  \
# 0  6fc84bfb       NaN       NaN  4f1aa25f  NaN  423fab69  ded4aac9       NaN
# 1  66c3058a       NaN       NaN  a645a590  NaN  c7dc6720  043ce596       NaN
# 2  005c6740  21ddcdc9  5840adea  2fd40314  NaN  32c7478e  1793a828  e8b83407
# 3  d1c83925       NaN       NaN  3777e5ab  NaN  3a171ecb  b2f178a3       NaN
# 4  526e8765       NaN       NaN  1797596a  NaN  32c7478e  45b2acf4       NaN
#
#         C26
# 0       NaN
# ...
